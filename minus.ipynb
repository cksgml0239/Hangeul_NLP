# %%
import pandas as pd

df=pd.read_excel("math_func_type.xlsx",sheet_name=1)
df.head()
# Out:
#                                                   질문  ...                      키워드1
# 0    그림과 같이 22를 넣었더니 18이 나왔습니다.  31을 넣으면 얼마가 나오겠습니까?  ...  넣었더니, 나왔습니다, 넣으면, 나오겠습니까
# 1        13을 넣으면 5가 나오는 상자가 있습니다. 9를 넣으면 얼마가 나오겠습니까?  ...    넣었더니, 나오는, 넣으면, 나오겠습니까
# 2  그림과 같이 17을 넣으면 6이 나오는 상자가 있습니다. 24를 넣으면 얼마가 나오...  ...    넣었더니, 나오는, 넣으면, 나오겠습니까
# 3  그림과 같이 18을 넣으면 13이 나오는 요술 주머니가 있습니다.  51을 넣으면 ...  ...       넣으면, 나오는, 넣으면, 나옵니까
# 4  다음 그림과 같이 어떤 수를 넣으면 일정한 수만큼 빼서 나오는 상자가 있습니다. 예...  ...       넣으면, 나오는, 넣으면, 나옵니까
#
# [5 rows x 4 columns]

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
# plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib inline
# Out:
# It's unknown system. Hangul fonts are not supported!

# %%
df.tail()
# Out:
#                                                     질문  ...                      키워드1
# 115  철수는 사과 38개를 가지고 있습니다. 철수는 영희에게 사과 몇 개를 줬습니다. 철...  ...             몇, 줬습니다, 몇, 준
# 116  아름이는 사탕 8개를 가졌습니다. 몇 개를 다운이에게 주었더니 3개가 남았습니다. ...  ...     몇, 주었더니, 남았습니다, 준, 몇
# 117  민지는 색종이 12장을 가지고 있었는데, 몇 장을 사용하였더니 9장이 남았습니다. ...  ...  몇, 사용하였더니, 남았습니다, 사용한, 몇
# 118  주차장에 있던 자동차 5대 중 몇 대가 나가서 3대가 남았습니다. 주차장에서 나간 ...  ...  중, 몇 , 나가서, 남았습니다, 나간, 몇
# 119  준기는 연필 10자루를 가지고 있습니다. 동생에게 몇 자루를 주었더니 6자루가 남았...  ...            몇, 주었더니, 남았습니다
#
# [5 rows x 4 columns]

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/e5/3d/4e983cd98d87b50b2ab0387d73fa946f745aa8164e8888a714d5129f9765/konlpy-0.5.1-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 119kB/s
# Collecting JPype1>=0.5.7
#   Downloading https://files.pythonhosted.org/packages/07/09/e19ce27d41d4f66d73ac5b6c6a188c51b506f56c7bfbe6c1491db2d15995/JPype1-0.7.0-cp36-cp36m-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 32.3MB/s
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-0.7.0 konlpy-0.5.1

# %%
from konlpy.tag import Kkma
kkma = Kkma()

from konlpy.tag import Okt
okt = Okt()


df["kkma"] = ''
df["okt"] = ''


for i in range(0, len(df)):
    #df['kkma'][i] = kkma.morphs(df["질문"][i])
    #df['okt'][i] = okt.morphs(df["질문"][i])
    df['kkma'][i] = kkma.pos(df["질문"][i])
    df['okt'][i] = okt.pos(df["질문"][i])
    
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
#                                                   질문  ...                                                okt
# 0    그림과 같이 22를 넣었더니 18이 나왔습니다.  31을 넣으면 얼마가 나오겠습니까?  ...  [(그림, Noun), (과, Josa), (같이, Adverb), (22, Num...
# 1        13을 넣으면 5가 나오는 상자가 있습니다. 9를 넣으면 얼마가 나오겠습니까?  ...  [(13, Number), (을, Josa), (넣으면, Verb), (5, Num...
# 2  그림과 같이 17을 넣으면 6이 나오는 상자가 있습니다. 24를 넣으면 얼마가 나오...  ...  [(그림, Noun), (과, Josa), (같이, Adverb), (17, Num...
# 3  그림과 같이 18을 넣으면 13이 나오는 요술 주머니가 있습니다.  51을 넣으면 ...  ...  [(그림, Noun), (과, Josa), (같이, Adverb), (18, Num...
# 4  다음 그림과 같이 어떤 수를 넣으면 일정한 수만큼 빼서 나오는 상자가 있습니다. 예...  ...  [(다음, Noun), (그림, Noun), (과, Josa), (같이, Adver...
#
# [5 rows x 6 columns]

# %%
nnm=[]

for i in range(0, len(df)):
    for j in range(0,len(df["kkma"][i])):
        if df["kkma"][i][j][1]=="NNM":
            nnm.append(df["kkma"][i][j][0])
nnm  #단위
# Out:
# ['살',
#  '살',
#  '살',
#  '개',
#  '개',
#  '개',
#  '장',
#  '장',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '살',
#  '살',
#  '살',
#  '살',
#  '장',
#  '장',
#  '장',
#  '장',
#  '장',
#  '명',
#  '권',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '장',
#  '장',
#  '살',
#  '살',
#  '살',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '장',
#  '명',
#  '개',
#  '개',
#  '살',
#  '살',
#  '살',
#  '명',
#  '명',
#  '명',
#  '권',
#  '권',
#  '대',
#  '대',
#  '번',
#  '마리',
#  '마리',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '살',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '쪽',
#  '장',
#  '마리',
#  '마리',
#  '마리',
#  '장',
#  '명',
#  '명',
#  '명',
#  '명',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '명',
#  '명',
#  '명',
#  '명',
#  '명',
#  '명',
#  '개',
#  '개',
#  '명',
#  '명',
#  '명',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '살',
#  '살',
#  '살',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '번',
#  '번',
#  '개',
#  '개',
#  '대',
#  '대',
#  '개',
#  '개',
#  '개',
#  '개',
#  '마리',
#  '마리',
#  '장',
#  '개',
#  '개',
#  '마리',
#  '마리',
#  '대',
#  '대',
#  '마리',
#  '마리',
#  '명',
#  '명',
#  '명',
#  '마리',
#  '마리',
#  '개',
#  '개',
#  '명',
#  '명',
#  '명',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '개',
#  '장',
#  '대',
#  '대']

# %%
mdt=[]

for i in range(0, len(df)):
    for j in range(0,len(df["kkma"][i])):
        if df["kkma"][i][j][1]=="MDT":
            mdt.append(df["kkma"][i][j][0])
            print(i,df["kkma"][i][j][0])
# 미지수 x
# Out:
# 4 어떤
# 6 어떤
# 16 어떤
# 17 어떤
# 18 어떤
# 19 어떤
# 20 어떤
# 21 어떤
# 22 어떤
# 23 어떤
# 26 어떤
# 27 어떤
# 28 어떤
# 29 어떤
# 30 몇
# 31 몇
# 32 몇
# 33 몇
# 34 몇
# 35 몇
# 36 몇
# 37 몇
# 38 몇
# 39 몇
# 40 몇
# 40 몇
# 41 몇
# 42 몇
# 43 몇
# 44 몇
# 45 몇
# 46 몇
# 47 몇
# 48 몇
# 49 몇
# 50 몇
# 51 몇
# 52 어느
# 52 몇
# 53 몇
# 54 몇
# 55 몇
# 56 몇
# 57 어느
# 57 몇
# 58 몇
# 59 몇
# 60 어느
# 60 몇
# 61 몇
# 62 몇
# 63 몇
# 64 몇
# 65 몇
# 66 몇
# 67 몇
# 68 몇
# 69 몇
# 70 몇
# 71 몇
# 72 몇
# 73 몇
# 74 몇
# 75 몇
# 76 그
# 76 몇
# 77 몇
# 78 몇
# 79 몇
# 80 몇
# 81 몇
# 82 몇
# 83 몇
# 84 몇
# 85 몇
# 86 그
# 86 몇
# 87 그
# 87 몇
# 88 몇
# 89 몇
# 90 몇
# 91 몇
# 92 몇
# 93 몇
# 94 몇
# 95 몇
# 96 몇
# 97 몇
# 98 그
# 98 몇
# 99 몇
# 100 그
# 100 몇
# 101 몇
# 102 그
# 102 몇
# 103 그
# 103 몇
# 104 몇
# 105 몇
# 106 몇
# 107 몇
# 108 몇
# 108 몇
# 109 몇
# 109 몇
# 110 몇
# 110 몇
# 111 몇
# 111 몇
# 112 몇
# 112 몇
# 113 몇
# 113 몇
# 114 그
# 114 몇
# 114 몇
# 115 몇
# 115 몇
# 116 몇
# 116 몇
# 117 몇
# 117 몇
# 118 몇
# 118 몇
# 119 몇

# %%
import re

df["model"]=''
df["model_answer"]=''

for i in range(0,len(df)):
    if re.compile("보다 [\w]{1,9} ['더 가지고 있습니다, 더 가지고 있습니까, 더 많이 가지고 있는지, 더 팔았습니까, 더 많았다고 합니다, 더 많습니까, 더 많은지, 더 많을까요, 더 많이 먹었습니까, 더 적게']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("[\w]{1,9} ['더 많이 가지고 있는지,더 붙일 수 있습니까']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
            
for i in range(0,len(df)):
    if re.compile("몇  [\w]{1,4}를 ['주었습니다. , 주었더니 ,줬습니다']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
 
            
for i in range(0,len(df)):
    if re.compile("나누어").findall(df["질문"][i])!=[]:
        if re.compile("['를 가졌다면, 를 주었다면, 먼저,  를 쥐었다면']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("['주었더니, 하였더니']").findall(df["질문"][i])!=[]:
        if re.compile("남았습니다.").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))
                
                
for i in range(0,len(df)):
    if re.compile("에게  [\w]{1,10}['을,를'] 한 [\w]{1,4}씩").findall(df["질문"][i])!=[]:
        if re.compile("몇  [\w]{1,4} 더 필요합니까").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                
              
            
            
            
for i in range(0,len(df)):
    if re.compile("와 똑같은  [\w]{1,10} 가지려면").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
             

for i in range(0,len(df)):
    if re.compile("와 같아질까요").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
             
                
for i in range(0,len(df)):
    if re.compile("같은 수의  [\w]{1,10} 갖기 위하여").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("만큼  [\w]{1,10}을 가지려면").findall(df["질문"][i])!=[]:
        if re.compile("만큼  [\w]{1,10}을 가지려면  [\w]{1,10} 몇 [\w]{1,4}가 더 있어야").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
            
            
            
for i in range(0,len(df)):
    if re.compile("['중 , 그중 , 그 중에서, 이 중, 이 중에서, 중에서']").findall(df["질문"][i])!=[]:
        if re.compile("['남았습니다, 주었습니다, 남습니까, 잃었습니다, 남은,  나가서, 부러졌습니다, 몇 [\w]{1,4}입니까']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
            
            
            
for i in range(0,len(df)):
    if re.compile("['잠시 후, 얼마 후, 잠시후, 며칠 후에, 며칠 후']").findall(df["질문"][i])!=[]:
        if re.compile("['남아있는,  남았습니까, 날아갔습니다., 졌습니다, 돌아가서']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
                        








            

#상자문제            
for i in range(0,len(df)):
    if re.compile("[\d]{1,4}['을,를'] 넣었더니 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0]),'+',int(a[2])]
            df["model_answer"][i]=(int(a[1])-int(a[0])+int(a[2]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[2]),'-(',int(a[0]),'-',int(a[1]),')']
            df["model_answer"][i]=(int(a[2])-int(a[0])+int(a[1]))
    elif re.compile("[\d]{1,4}['을,를'] 넣으면 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0]),'+',int(a[2])]
            df["model_answer"][i]=(int(a[1])-int(a[0])+int(a[2]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[2]),'-(',int(a[0]),'-',int(a[1]),')']
            df["model_answer"][i]=(int(a[2])-int(a[0])+int(a[1]))

# %%
df.head()
df.to_excel("a2.xlsx",index=False)

# %%
df.head()
# Out:
#                                                   질문  ... model_answer
# 0    그림과 같이 22를 넣었더니 18이 나왔습니다.  31을 넣으면 얼마가 나오겠습니까?  ...           27
# 1        13을 넣으면 5가 나오는 상자가 있습니다. 9를 넣으면 얼마가 나오겠습니까?  ...            1
# 2  그림과 같이 17을 넣으면 6이 나오는 상자가 있습니다. 24를 넣으면 얼마가 나오...  ...           13
# 3  그림과 같이 18을 넣으면 13이 나오는 요술 주머니가 있습니다.  51을 넣으면 ...  ...           46
# 4  다음 그림과 같이 어떤 수를 넣으면 일정한 수만큼 빼서 나오는 상자가 있습니다. 예...  ...           18
#
# [5 rows x 8 columns]
